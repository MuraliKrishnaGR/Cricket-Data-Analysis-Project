# %%
# Importing necessary libraries
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from queries import queries  # Import the queries dictionary

# Database connection setup
DB_PATH = "cricket_data.sqlite"

def connect_to_database(db_path):
    """Connect to the SQLite database."""
    try:
        conn = sqlite3.connect(db_path)
        print("Connected to database successfully.")
        return conn
    except sqlite3.Error as e:
        print(f"Error connecting to database: {e}")
        return None

def execute_query(conn, query):
    """Execute a single SQL query and return the result as a DataFrame."""
    try:
        df = pd.read_sql_query(query, conn)
        return df
    except Exception as e:
        print(f"Error executing query: {e}")
        return pd.DataFrame()

# Connect to the database
conn = connect_to_database(DB_PATH)
# Out:
# Connected to database successfully.

# %%
# Display all available queries
for query_name in queries.keys():
    print(query_name)
# Out:
# top_test_players
# test_match_cities
# test_match_team_wins
# highest_run_victories_odi
# overs_distribution_odi
# frequent_venues_odi
# top_t20_players
# t20_team_wins
# smallest_margin_wickets_t20
# gender_distribution_t20

# %%
#top_test_players
query_name = "top_test_players"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: top_test_players
#        player_of_match  awards_count
# 0          ['V Kohli']             8
# 1        ['RA Jadeja']             8
# 2    ['KS Williamson']             8
# 3        ['BA Stokes']             8
# 4          ['TM Head']             7
# 5        ['SPD Smith']             7
# 6          ['JE Root']             7
# 7         ['R Ashwin']             6
# 8         ['K Rabada']             6
# 9  ['FDM Karunaratne']             6

# %%
# Visualization for "top_test_players" query
if query_name == "top_test_players":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="awards_count", y="player_of_match", data=result_df, palette="viridis")
    plt.title("Top 10 Players with Most Awards in Test Matches")
    plt.xlabel("Awards Count")
    plt.ylabel("Player of the Match")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\1073141320.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="awards_count", y="player_of_match", data=result_df, palette="viridis")

# %%
# test_match_team_wins
query_name = "test_match_cities"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: test_match_cities
#            city  match_count
# 0        London           34
# 1       Colombo           16
# 2    Wellington           14
# 3         Galle           14
# 4         Dhaka           13
# 5  Christchurch           13
# 6  Johannesburg           12
# 7     Cape Town           12
# 8    Manchester           11
# 9    Chattogram           11

# %%
query_name == "test_match_cities"
            # Pie chart
plt.figure(figsize=(8, 8))
plt.pie(result_df["match_count"], labels=result_df["city"], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(result_df)))
plt.title("Match Distribution Among Top Cities")
plt.show()

# %%
#test_match_cities
query_name = "test_match_team_wins"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: test_match_team_wins
#   outcome_winner  win_count
# 0          India         71
# 1      Australia         69
# 2        England         68
# 3   South Africa         54
# 4      Sri Lanka         43
# 5    New Zealand         42
# 6       Pakistan         27
# 7    West Indies         22
# 8     Bangladesh         14
# 9       Zimbabwe          1

# %%
if query_name == "test_match_team_wins":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="win_count", y="outcome_winner", data=result_df, palette="plasma", orient="h")
    plt.title("Test Match Team Wins Distribution")
    plt.xlabel("Wins")
    plt.ylabel("Team")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\1068925969.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="win_count", y="outcome_winner", data=result_df, palette="plasma", orient="h")

# %%
# highest_run_victories_odi
query_name = "highest_run_victories_odi"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: highest_run_victories_odi
#    outcome_by_runs          city   season
# 0              306        Dublin     2018
# 1              244      Bulawayo     2018
# 2              242    Nottingham     2018
# 3              226        Harare  2017/18
# 4              224        Mumbai  2018/19
# 5              219       Colombo  2018/19
# 6              208     Leicester     2019
# 7              205  Christchurch  2017/18
# 8              204  Christchurch  2017/18
# 9              201      Bulawayo     2018

# %%
if query_name == "highest_run_victories_odi":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="outcome_by_runs", y="city", data=result_df, palette="coolwarm", orient="h")
    plt.title("Top 10 Highest Run Victories in ODIs")
    plt.xlabel("Run Margin")
    plt.ylabel("City")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\1293384611.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="outcome_by_runs", y="city", data=result_df, palette="coolwarm", orient="h")

# %%
# overs_distribution_odi
query_name = "overs_distribution_odi"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: overs_distribution_odi
#    overs  match_count
# 0   50.0          500

# %%
if query_name == "overs_distribution_odi":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="overs", y="match_count", data=result_df, palette="Blues_d")
    plt.title("Overs Distribution in ODIs")
    plt.xlabel("Overs")
    plt.ylabel("Match Count")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\1292406360.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="overs", y="match_count", data=result_df, palette="Blues_d")

# %%
# frequent_venues_odi
query_name = "frequent_venues_odi"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: frequent_venues_odi
#             city  match_count
# 0        Colombo           25
# 1         London           23
# 2          Dubai           16
# 3  Potchefstroom           15
# 4         Dublin           14
# 5       Bulawayo           13
# 6      Leicester           11
# 7        Bristol           11
# 8          Dhaka           10
# 9     Birmingham           10

# %%
if query_name == "frequent_venues_odi":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="match_count", y="city", data=result_df, palette="icefire", orient="h")
    plt.title("Frequent ODI Venues")
    plt.xlabel("Match Count")
    plt.ylabel("City")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\3703467800.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="match_count", y="city", data=result_df, palette="icefire", orient="h")

# %%
# top_t20_players
query_name = "top_t20_players"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: top_t20_players
#      player_of_match  awards_count
# 0       ['AJ Healy']             8
# 1    ['Shadab Khan']             6
# 2      ['RG Sharma']             6
# 3          ['M Raj']             6
# 4     ['SFM Devine']             5
# 5          ['L Lee']             5
# 6        ['E Lewis']             5
# 7        ['C Munro']             5
# 8       ['Nida Dar']             4
# 9  ['Kuldeep Yadav']             4

# %%
if query_name == "top_t20_players":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="awards_count", y="player_of_match", data=result_df, palette="spring", orient="h")
    plt.title("Top 10 Players with Most Awards in T20 Matches")
    plt.xlabel("Awards Count")
    plt.ylabel("Player of the Match")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\4232482001.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="awards_count", y="player_of_match", data=result_df, palette="spring", orient="h")

# %%
# t20_team_wins
query_name = "t20_team_wins"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: t20_team_wins
#   outcome_winner  win_count
# 0          India         59
# 1      Australia         52
# 2       Pakistan         38
# 3    New Zealand         38
# 4        England         38
# 5   South Africa         32
# 6    West Indies         20
# 7     Bangladesh         19
# 8        Namibia         16
# 9       Scotland         15

# %%
if query_name == "t20_team_wins":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="win_count", y="outcome_winner", data=result_df, palette="dark", orient="h")
    plt.title("Top 10 Teams with Most Wins in T20 Matches")
    plt.xlabel("Win Count")
    plt.ylabel("Team")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\2842516617.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="win_count", y="outcome_winner", data=result_df, palette="dark", orient="h")

# %%
# smallest_margin_wickets_t20
query_name = "smallest_margin_wickets_t20"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: smallest_margin_wickets_t20
#    match_id  outcome_by_wickets   season
# 0       126                   1  2017/18
# 1       300                   1  2018/19
# 2       306                   1  2018/19
# 3       370                   1     2019
# 4         2                   2  2016/17
# 5        80                   2  2017/18
# 6       120                   2  2017/18
# 7       180                   2     2018
# 8       435                   2     2019
# 9       142                   3     2018

# %%
if query_name == "smallest_margin_wickets_t20":
    plt.figure(figsize=(10, 6))
    sns.barplot(x="outcome_by_wickets", y="match_id", data=result_df, palette="autumn", orient="h")
    plt.title("Smallest Wicket Margin Wins in T20 Matches")
    plt.xlabel("Wicket Margin")
    plt.ylabel("Match ID")
    plt.show()
# Out:
# C:\Users\Murali Krishna\AppData\Local\Temp\ipykernel_18080\1884595643.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="outcome_by_wickets", y="match_id", data=result_df, palette="autumn", orient="h")

# %%
# gender_distribution_t20
query_name = "gender_distribution_t20"

if query_name in queries:
    print(f"Executing query: {query_name}")
    query_sql = queries[query_name]
    result_df = execute_query(conn, query_sql)
    print(result_df)
else:
    print("Query not found.")
# Out:
# Executing query: gender_distribution_t20
#    gender  match_count
# 0  female          253
# 1    male          247

# %%
if query_name == "gender_distribution_t20":
    plt.figure(figsize=(8, 8))
    plt.pie(result_df["match_count"], labels=result_df["gender"], autopct='%1.1f%%', startangle=140, colors=sns.color_palette("winter", len(result_df)))
    plt.title("Gender Distribution in T20 Matches")
    plt.show()

# %%
import os
db_path = os.path.abspath("cricket_data.sqlite")
print(db_path)
# Out:
# d:\analysis\cricket_data.sqlite
